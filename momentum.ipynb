# %%
import manim as mn
from manim import *

# %%
# %%manim -qm -v WARNING CreateCircle
#
# class MovingRectangle(Rectangle):
#     def __init__(self, direction, velocity: float, **kwargs):
#         super().__init__(**kwargs)
#         self.direction = direction
#         self.velocity = velocity
#
# class CreateCircle(Scene):
#     def construct(self):
#         circle = Circle()  # create a circle
#         circle.set_fill(PINK, opacity=0.5)  # set the color and transparency
#         self.play(Create(circle))  # show the circle on screen
#         print(LARGE_BUFF)
# Out:
# Manim Community v0.20.1
# 1
# <video src="media/jupyter/CreateCircle@2026-04-12@23-17-46.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
